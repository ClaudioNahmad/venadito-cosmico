# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook

# %%
h =0.67556
h2=h**2

omega_fld=0.6911
omega_b=0.0486
omega_cdm=0.2589
omega_m=0.3089

omegafld=omega_fld*h2
omegab=omega_b*h2
omegacdm=omega_cdm*h2
omegam=omega_m*h2
omegatot=omegafld+omegab+omegacdm+omegam

print h2
print omegafld
print omegab
print omegacdm
print omegam
print omegatot
# Out:
# 0.4563813136
# 0.315405125829
# 0.022180131841
# 0.118157122091
# 0.140976187771
# 0.596718567532

# %%
#CPL
cplpk_none=np.loadtxt('./../nealika_N1/output/cpl/CPL_pk.dat')

cplcl_none=np.loadtxt('./../nealika_N1/output/cpl/CPL_cl.dat')
#-------------------------------------------------------------------
#Params1
cplpk_1=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL1_pk.dat')
wnpk_1=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN1_pk.dat')

cplcl_1=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL1_cl.dat')
wncl_1=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN1_cl.dat')
#-------------------------------------------------------------------
#Params2
cplpk_2=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL2_pk.dat')
wnpk_2=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN2_pk.dat')

cplcl_2=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL2_cl.dat')
wncl_2=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN2_cl.dat')
#-------------------------------------------------------------------
#Params9
cplpk_9=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL9_pk.dat')
wnpk_9=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN9_pk.dat')

cplcl_9=np.loadtxt('./../nealika_N1/output/test_wn_cpl/CPL9_cl.dat')
wncl_9=np.loadtxt('./../nealika_N1/output/test_wn_cpl/WN9_cl.dat')
#-------------------------------------------------------------------
#Non-CPL
noncpl_pk=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_z1_pk.dat')
noncpl_pk2=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_z2_pk.dat')
noncpl_pk3=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_z3_pk.dat')
noncpl_pk4=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_z4_pk.dat')
noncpl_pk5=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_z5_pk.dat')

noncpl_cl=np.loadtxt('./../nealika_N1/output/non-cpl/CPL_cl.dat')


#*******************************
#w2
w2pk=np.loadtxt('./../piwami_N2/output/first_test_pk.dat')

# %%
fig, ax = plt.subplots(figsize=(13,10))

#--------------------------------------------------------------------------------------
# CPL
ax.loglog(cplpk_1[:,0],cplpk_1[:,1],label='cpl params1',alpha=0.3,linewidth=4)
#ax.loglog(cplpk_2[:,0],cplpk_2[:,1],label='cpl params2',alpha=0.3,linewidth=4)

# WN=1
#ax.loglog(wnpk_1[:,0],wnpk_1[:,1],label='w1 params 1',alpha=0.3,linewidth=4)
#ax.loglog(wnpk_2[:,0],wnpk_2[:,1],label='w1 params 2',alpha=0.3,linewidth=4)
ax.loglog(wnpk_9[:,0],wnpk_9[:,1],label='w1 params 9',alpha=0.3,linewidth=4)

ax.loglog(cplpk_none[:,0],cplpk_none[:,1],label='cpl with no params',alpha=0.3,linewidth=4)

ax.loglog(w2pk[:,0],w2pk[:,1],label='w2',alpha=0.3,linewidth=4)
#--------------------------------------------------------------------------------------
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=10**-3,right=10**3)
ax.grid(which='major',ls=":", c='black')
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
fig, ax = plt.subplots(figsize=(13,10))
ax.loglog(cplpk_1[:,0],cplpk_1[:,1],label='cpl (parameters1)',alpha=0.5,linewidth=1)
ax.loglog(cplpk_2[:,0],cplpk_2[:,1],label='cpl (parameters2)',alpha=0.5,linewidth=1)
ax.loglog(cplpk_9[:,0],cplpk_9[:,1],label='cpl (parameters3)',alpha=1,linewidth=1)


ax.legend(loc='lower left', fancybox=True, framealpha=1)
ax.set_ylabel(r'P $(Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'k $(h/Mpc) $',fontsize=15)
ax.set_ylim(bottom=10**-2,top=10**0)
ax.set_xlim(left=1,right=10)
ax.grid(which='major',ls=":", c='black')
ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
fig, ax = plt.subplots(figsize=(12,10))

ax.semilogx(cplcl_1[:,0],cplcl_1[:,1],'-r',label='cpl params 1',alpha=1,linewidth=1)
ax.semilogx(wncl_1[:,0],wncl_1[:,1],'-b',label='w(n=1) params 1',alpha=0.3,linewidth=2)

ax.semilogx(cplcl_2[:,0],cplcl_2[:,1],'-g',label='cpl params 2',alpha=0.3,linewidth=1)
ax.semilogx(wncl_2[:,0],wncl_2[:,1],'-k',label='w(n=1) params 2',alpha=0.3,linewidth=2)

ax.semilogx(cplcl_9[:,0],cplcl_9[:,1],label='cpl params 9',alpha=0.3,linewidth=1)
ax.semilogx(wncl_9[:,0],wncl_9[:,1],label='w(n=1) params 9',alpha=0.3,linewidth=2)
#ax.semilogx(cplcl_none[:,0],cplcl_none[:,1],'-y',label='cpl no params',alpha=0.3,linewidth=4)
#ax.semilogx(noncpl_cl[:,0],noncpl_cl[:,1],'-',label='cpl no params',alpha=0.3,linewidth=4)

ax.set_xlim(left=10, right=3000)
ax.legend(loc='upper right', fancybox=True, framealpha=0.5)
ax.grid(which='major',ls=":", c='black');
# Out:
# <img src="data:image/png;base64,..." width="864">
