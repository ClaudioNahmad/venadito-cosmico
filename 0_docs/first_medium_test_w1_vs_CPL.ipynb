# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook

# %%
# w ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

#N=1 **************************************************************************
nealpk1=np.loadtxt('./../N1_nearika/output/nealika2_pk.dat')
nealcl1=np.loadtxt('./../N1_nearika/output/nealika2_cl.dat')

#params1 b0=, b1=
n1pk1=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params1_pk.dat')
n1cl1=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params1_cl.dat')

#params2 b0=, b1=
n1pk2=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params2_pk.dat')
n1cl2=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params2_cl.dat')

#params3 b0=, b1=
n1pk3=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params3_pk.dat')
n1cl3=np.loadtxt('./../N1_nearika/output/test1_wn/N1_params3_cl.dat')

#N=2 **************************************************************************
#params1 b0=, b1=, b2=
n2pk1=np.loadtxt('./../N2_nakawe/output/wn2/N2_params2_pk.dat')
n2cl1=np.loadtxt('./../N2_nakawe/output/wn2/N2_params2_cl.dat')

#N=3 **************************************************************************
#params1 b0=, b1=, b2=, b3=
n3pk1=np.loadtxt('./../N3_wimari/output/wn3/N3_params1_pk.dat')
n3cl1=np.loadtxt('./../N3_wimari/output/wn3/N3_params1_cl.dat')

#N=4 **************************************************************************
#params1 b0=, b1=, b2=, b3=, b4
n4pk1=np.loadtxt('./../N4_kauyumari/output/wn4/N4_params1_pk.dat')
n4cl1=np.loadtxt('./../N4_kauyumari/output/wn4/N4_params1_cl.dat')

#CPL **************************************************************************
#params1 b0=, b1=
cplpk1=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params1_pk.dat')
cplcl1=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params1_cl.dat')

#params2 b0=, b1=
cplpk2=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params2_pk.dat')
cplcl2=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params2_cl.dat')

#params3 b0=, b1=
cplpk3=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params3_pk.dat')
cplcl3=np.loadtxt('./../N1_nearika/output/test1_cpl/cpl_params3_cl.dat')


#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

#LCDM **************************************************************************
lpk=np.loadtxt('./../../class-public/output/lcdm_pk.dat')
lcl=np.loadtxt('./../../class-public/output/lcdm_cl.dat')

# %%
fig, ax = plt.subplots(figsize=(9,7))

#N=1 vs CPL----------------------------------------------------------------------------
# Params 1
ax.loglog(n1pk1[:,0],n1pk1[:,1],'m',label=r'$w(N=1)_1$',alpha=1,linewidth=1)
ax.loglog(cplpk1[:,0],cplpk1[:,1],'m',label=r'$CPL_1$',alpha=0.3,linewidth=5)

# Params 2
ax.loglog(n1pk2[:,0],n1pk2[:,1],'b',label=r'$w(N=1)_2$',alpha=1,linewidth=1)
ax.loglog(cplpk2[:,0],cplpk2[:,1],'b',label=r'$CPL_2$',alpha=0.3,linewidth=5)

# Params 3
ax.loglog(n1pk3[:,0],n1pk3[:,1],'g',label=r'$w(N=1)_3$',alpha=1,linewidth=1)
ax.loglog(cplpk3[:,0],cplpk3[:,1],'g',label=r'$CPL_3$',alpha=0.3,linewidth=5)

ax.loglog(lpk[:,0],lpk[:,1],'--',label=r'$\Lambda$-CDM',alpha=1,linewidth=1)


#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
plt.savefig('power1.png')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#N=1 vs N=2 vs N=3 vs Lambda-CDM--------------------------------------------------------
# Params 1
ax.loglog(n1pk1[:,0],n1pk1[:,1],label=r'$w(N=1)$',alpha=1,linewidth=1)
ax.loglog(n2pk1[:,0],n2pk1[:,1],label=r'$w(N=2)$',alpha=1,linewidth=1)
ax.loglog(n3pk1[:,0],n3pk1[:,1],label=r'$w(N=3)$',alpha=1,linewidth=1)
ax.loglog(n4pk1[:,0],n4pk1[:,1],label=r'$w(N=4)$',alpha=1,linewidth=1)
ax.loglog(lpk[:,0],lpk[:,1],'--',label=r'$\Lambda$-CDM',alpha=1,linewidth=1)


#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
plt.savefig('power2.png')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#Params 1
ax.semilogx(n1cl1[:,0],n1cl1[:,1],'b',label=r'$w(N=1)_1$',alpha=1,linewidth=1)
ax.semilogx(cplcl1[:,0],cplcl1[:,1],'b',label=r'$CPL_1$',alpha=0.3,linewidth=3)

#Params 2
ax.semilogx(n1cl2[:,0],n1cl2[:,1],'g',label=r'$w(N=1)_2$',alpha=1,linewidth=1)
ax.semilogx(cplcl2[:,0],cplcl2[:,1],'g',label=r'$CPL_2$',alpha=0.3,linewidth=3)

#Params 3
ax.semilogx(n1cl3[:,0],n1cl3[:,1],'y',label=r'$w(N=1)_3$',alpha=1,linewidth=1)
ax.semilogx(cplcl3[:,0],cplcl3[:,1],'y',label=r'$CPL_3$',alpha=0.3,linewidth=3)

#LCDM
ax.semilogx(lcl[:,0],lcl[:,1],'k:',label=r'$\Lambda$-CDM',alpha=1,linewidth=1.5)

#W2,3,4
ax.semilogx(n2cl1[:,0],n2cl1[:,1],label=r'$w(N=2)$',alpha=1,linewidth=1)
ax.semilogx(n3cl1[:,0],n3cl1[:,1],label=r'$w(N=3)$',alpha=1,linewidth=1)
ax.semilogx(n4cl1[:,0],n4cl1[:,1],label=r'$w(N=4)$',alpha=1,linewidth=1)


ax.set_xlim(left=2, right=3000)
ax.set_xlabel(r'multipole moment $\ell$',fontsize=15)
ax.set_ylabel(r'$D_{\ell}^{TT} $',fontsize=15)
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.grid(which='both',ls=":", c='black', alpha=0.4);

#CAMBIAR NOMBRE AQUIIIIIIIIIIIIIII

plt.savefig('comparison_all.pdf')
plt.savefig('comparison_all.png')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
### AQUI SACAMOS LAS DISTANCIAS Delta D_{l}^{TT}

vw1=n1cl1[:,1]
vw2=n1cl2[:,1]
vw3=n1cl3[:,1]

vcpl1=cplcl1[:,1]
vcpl2=cplcl2[:,1]
vcpl3=cplcl3[:,1]

vlcdm=lcl[:,1]

#dist = numpy.linalg.norm(a-b)

# %%
len(v1), len(v2), len(v3)

dist1=(vlcdm-vw1)
dist2=(vlcdm-vw2)
dist3=(vlcdm-vw3)
dist0=(vlcdm-vlcdm)
dist11=(vlcdm-vcpl1)
dist12=(vlcdm-vcpl2)
dist13=(vlcdm-vcpl3)

# %%
fig, ax = plt.subplots(figsize=(9,7))

ax.semilogx(lcl[:,0],dist0,label=r'$\Lambda$-CDM',alpha=1,linewidth=1.5)
ax.semilogx(lcl[:,0],dist1,label=r'$w(N=1)_1$',alpha=1,linewidth=1.5)
ax.semilogx(lcl[:,0],dist2,label=r'$w(N=1)_2$',alpha=1,linewidth=1.5)
ax.semilogx(lcl[:,0],dist3,label=r'$w(N=1)_3$',alpha=1,linewidth=1.5)

ax.semilogx(lcl[:,0],dist11,label=r'$CPL_1$',alpha=0.5,linewidth=1.5)
ax.semilogx(lcl[:,0],dist12,label=r'$CPL_2$',alpha=0.5,linewidth=1.5)
ax.semilogx(lcl[:,0],dist13,label=r'$CPL_3$',alpha=0.5,linewidth=1.5)

ax.set_xlim(left=2, right=3000)
#ax.set_ylim(top=1,bottom=-1)
ax.set_xlabel(r'multipole moment $\ell$',fontsize=15)
ax.set_ylabel(r'$D_{\ell}^{TT} $',fontsize=15)
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.grid(which='both',ls=":", c='black', alpha=0.4);

#CAMBIAR NOMBRE AQUIIIIIIIIIIIIIII

#plt.savefig('comparison2.pdf')
#plt.savefig('comparison2.png')
# Out:
# <img src="data:image/png;base64,..." width="900">
