# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************
# %matplotlib notebook

# %%
# w ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

#N=1 **************************************************************************
#params1 b0=, b1=
n1pk1=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params1_pk.dat')
n1cl1=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params1_cl.dat')

#params2 b0=, b1=
n1pk2=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params2_pk.dat')
n1cl2=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params2_cl.dat')

#params3 b0=, b1=
n1pk3=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params3_pk.dat')
n1cl3=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params3_cl.dat')

#params4 b0=, b1=
n1pk4=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params4_pk.dat')
n1cl4=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params4_cl.dat')

#params5 b0=, b1=
n1pk5=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params5_pk.dat')
n1cl5=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params5_cl.dat')

#params6 b0=, b1=
n1pk6=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params6_pk.dat')
n1cl6=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params6_cl.dat')

#params7 b0=, b1=
n1pk7=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params7_pk.dat')
n1cl7=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params7_cl.dat')

#params8 b0=, b1=
n1pk8=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params8_pk.dat')
n1cl8=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params8_cl.dat')

#params9 b0=, b1=
n1pk9=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params9_pk.dat')
n1cl9=np.loadtxt('./../nealika_N1/output/test1_wn/N1_params9_cl.dat')


#CPL **************************************************************************
#params1 b0=, b1=
cplpk1=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params1_pk.dat')
cplcl1=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params1_cl.dat')

#params2 b0=, b1=
cplpk2=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params2_pk.dat')
cplcl2=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params2_cl.dat')

#params3 b0=, b1=
cplpk3=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params3_pk.dat')
cplcl3=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params3_cl.dat')

#params4 b0=, b1=
cplpk4=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params4_pk.dat')
cplcl4=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params4_cl.dat')

#params5 b0=, b1=
cplpk5=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params5_pk.dat')
cplcl5=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params5_cl.dat')
#params6 b0=, b1=
cplpk6=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params6_pk.dat')
cplcl6=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params6_cl.dat')

#params7 b0=, b1=
cplpk7=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params7_pk.dat')
cplcl7=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params7_cl.dat')

#params8 b0=, b1=
cplpk8=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params8_pk.dat')
cplcl8=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params8_cl.dat')

#params9 b0=, b1=
cplpk9=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params9_pk.dat')
cplcl9=np.loadtxt('./../nealika_N1/output/test1_cpl/cpl_params9_cl.dat')

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

#LCDM **************************************************************************
#lpk=np.loadtxt('./../../class-public/output/expl_pk.dat')
lcl=np.loadtxt('./../../class-public/output/explanatory00_cl.dat')

# %%
fig, ax = plt.subplots(figsize=(9,7))

#--------------------------------------------------------------------------------------
# Params 1
ax.loglog(n1pk1[:,0],n1pk1[:,1],'m',label='w1',alpha=1,linewidth=1)
ax.loglog(cplpk1[:,0],cplpk1[:,1],'m',label='CPL1',alpha=0.3,linewidth=5)

# Params 2
ax.loglog(n1pk2[:,0],n1pk2[:,1],'b',label='w2',alpha=1,linewidth=1)
ax.loglog(cplpk2[:,0],cplpk2[:,1],'b',label='CPL2',alpha=0.3,linewidth=5)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#--------------------------------------------------------------------------------------
# Params 3
ax.loglog(n1pk3[:,0],n1pk3[:,1],'g',label='w3',alpha=1,linewidth=1,)
ax.loglog(cplpk3[:,0],cplpk3[:,1],'g',label='CPL3',alpha=0.2,linewidth=5)

# Params 4
ax.loglog(n1pk4[:,0],n1pk4[:,1],'b',label='w4',alpha=1,linewidth=1)
ax.loglog(cplpk4[:,0],cplpk4[:,1],'b',label='CPL4',alpha=0.2,linewidth=5)


# LCDM
#ax.loglog(lpk[:,0],lpk[:,1],label=r'$\Lambda$-CDM',alpha=0.7,linewidth=1.5)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#--------------------------------------------------------------------------------------
# Params 5
ax.loglog(n1pk5[:,0],n1pk5[:,1],'r',label='w5',alpha=1,linewidth=1,)
ax.loglog(cplpk6[:,0],cplpk6[:,1],'r',label='CPL5',alpha=0.2,linewidth=5)

# Params 6
ax.loglog(n1pk4[:,0],n1pk4[:,1],'k',label='w6',alpha=1,linewidth=1)
ax.loglog(cplpk4[:,0],cplpk4[:,1],'k',label='CPL6',alpha=0.2,linewidth=5)

#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#--------------------------------------------------------------------------------------
# Params 7
ax.loglog(n1pk7[:,0],n1pk7[:,1],'r',label='w7',alpha=1,linewidth=1)
ax.loglog(cplpk7[:,0],cplpk7[:,1],'r',label='CPL7',alpha=0.2,linewidth=5)

# Params 8
ax.loglog(n1pk8[:,0],n1pk8[:,1],'b',label='w8',alpha=1,linewidth=1)
ax.loglog(cplpk8[:,0],cplpk8[:,1],'b',label='CPL8',alpha=0.2,linewidth=5)

# Params 9
ax.loglog(n1pk9[:,0],n1pk9[:,1],'g',label='w9',alpha=1,linewidth=1)
ax.loglog(cplpk9[:,0],cplpk9[:,1],'g',label='CPL9',alpha=0.2,linewidth=5)
#--------------------------------------------------------------------------------------
ax.legend(loc='best', fancybox=True, framealpha=1)
ax.set_ylabel(r'$P(k) (Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'$k (h/Mpc) $',fontsize=15)
#ax.set_ylim(bottom=10**-5)
ax.set_xlim(left=2*10**-5,right=1)
ax.grid(which='major',ls=":", c='black',alpha=0.4)
#ax.set_title(r'CPL vs w(N=1) for parameters 1');
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
fig, ax = plt.subplots(figsize=(9,7))

#Params 1
ax.semilogx(n1cl1[:,0],n1cl1[:,1],'b',label='w1',alpha=1,linewidth=1)
ax.semilogx(cplcl1[:,0],cplcl1[:,1],'b',label='cpl1',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl2[:,0],n1cl2[:,1],'g',label='w2',alpha=1,linewidth=1)
ax.semilogx(cplcl2[:,0],cplcl2[:,1],'g',label='cpl2',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl3[:,0],n1cl3[:,1],'y',label='w3',alpha=1,linewidth=1)
ax.semilogx(cplcl3[:,0],cplcl3[:,1],'y',label='cpl3',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl4[:,0],n1cl4[:,1],'r',label='w4',alpha=1,linewidth=1)
ax.semilogx(cplcl4[:,0],cplcl4[:,1],'r',label='cpl4',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl5[:,0],n1cl5[:,1],'m',label='w5',alpha=1,linewidth=1)
ax.semilogx(cplcl5[:,0],cplcl5[:,1],'m',label='cpl5',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl6[:,0],n1cl6[:,1],'k',label='w6',alpha=1,linewidth=1)
ax.semilogx(cplcl6[:,0],cplcl6[:,1],'k',label='cpl6',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl7[:,0],n1cl7[:,1],'c',label='w7',alpha=1,linewidth=1)
ax.semilogx(cplcl7[:,0],cplcl7[:,1],'c',label='cpl7',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl8[:,0],n1cl8[:,1],'purple',label='w8',alpha=1,linewidth=1)
ax.semilogx(cplcl8[:,0],cplcl8[:,1],'purple',label='cpl8',alpha=0.3,linewidth=3)

#Params 1
ax.semilogx(n1cl9[:,0],n1cl9[:,1],'orange',label='w9',alpha=1,linewidth=1)
ax.semilogx(cplcl9[:,0],cplcl9[:,1],'orange',label='cpl9',alpha=0.3,linewidth=3)

ax.semilogx(lcl[:,0],lcl[:,1],'k:',label=r'$\Lambda$-CDM',alpha=1,linewidth=1.5)

ax.set_xlim(left=2, right=3000)
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.grid(which='both',ls=":", c='black', alpha=0.4);

plt.savefig('comparison1.pdf')
plt.savefig('comparison1.jpg')
# Out:
# <img src="data:image/png;base64,..." width="900">
