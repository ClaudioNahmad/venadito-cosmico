# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
pk=np.loadtxt('./../output/test_claudio_pk.dat')
cl=np.loadtxt('./../output/test_claudio_cl.dat')
cl_expl=np.loadtxt('./../output/explanatory00_cl.dat')

# %%
plt.loglog(pk[:,0],pk[:,1])

# %%
plt.semilogx(cl[:,0],cl[:,1])
