# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rc

#******************************************************

rc('font',**{'family':'serif','serif':['Times']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

#LaTeX
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

#*******************************************************

# %%
pkcpl_1=np.loadtxt('./../kodama/output/parameter_set_1/CPL_pk.dat')
clcpl_1=np.loadtxt('./../kodama/output/parameter_set_1/CPL_cl.dat')
pkwn_1=np.loadtxt('./../kodama/output/parameter_set_1/wN1_pk.dat')
clwn_1=np.loadtxt('./../kodama/output/parameter_set_1/wN1_cl.dat')

pkcpl_2=np.loadtxt('./../kodama/output/parameter_set_2/CPL_pk.dat')
clcpl_2=np.loadtxt('./../kodama/output/parameter_set_2/CPL_cl.dat')
pkwn_2=np.loadtxt('./../kodama/output/parameter_set_2/wN1_pk.dat')
clwn_2=np.loadtxt('./../kodama/output/parameter_set_2/wN1_cl.dat')

pkcpl_3=np.loadtxt('./../kodama/output/parameter_set_3/CPL_pk.dat')
clcpl_3=np.loadtxt('./../kodama/output/parameter_set_3/CPL_cl.dat')
pkwn_3=np.loadtxt('./../kodama/output/parameter_set_3/wN1_pk.dat')
clwn_3=np.loadtxt('./../kodama/output/parameter_set_3/wN1_cl.dat')

pkcpl_4=np.loadtxt('./../kodama/output/parameter_set_4/CPL_pk.dat')
clcpl_4=np.loadtxt('./../kodama/output/parameter_set_4/CPL_cl.dat')
pkwn_4=np.loadtxt('./../kodama/output/parameter_set_4/wN1_pk.dat')
clwn_4=np.loadtxt('./../kodama/output/parameter_set_4/wN1_cl.dat')

pkcpl_5=np.loadtxt('./../kodama/output/parameter_set_5/CPL_pk.dat')
clcpl_5=np.loadtxt('./../kodama/output/parameter_set_5/CPL_cl.dat')
pkwn_5=np.loadtxt('./../kodama/output/parameter_set_5/wN1_pk.dat')
clwn_5=np.loadtxt('./../kodama/output/parameter_set_5/wN1_cl.dat')

pkcpl_6=np.loadtxt('./../kodama/output/parameter_set_6/CPL_pk.dat')
clcpl_6=np.loadtxt('./../kodama/output/parameter_set_6/CPL_cl.dat')
pkwn_6=np.loadtxt('./../kodama/output/parameter_set_6/wN1_pk.dat')
clwn_6=np.loadtxt('./../kodama/output/parameter_set_6/wN1_cl.dat')

pkcpl_7=np.loadtxt('./../kodama/output/parameter_set_7/CPL_pk.dat')
clcpl_7=np.loadtxt('./../kodama/output/parameter_set_7/CPL_cl.dat')
pkwn_7=np.loadtxt('./../kodama/output/parameter_set_7/wN1_pk.dat')
clwn_7=np.loadtxt('./../kodama/output/parameter_set_7/wN1_cl.dat')

pkcpl_8=np.loadtxt('./../kodama/output/parameter_set_8/CPL_pk.dat')
clcpl_8=np.loadtxt('./../kodama/output/parameter_set_8/CPL_cl.dat')
pkwn_8=np.loadtxt('./../kodama/output/parameter_set_8/wN1_pk.dat')
clwn_8=np.loadtxt('./../kodama/output/parameter_set_8/wN1_cl.dat')

pkcpl_9=np.loadtxt('./../kodama/output/parameter_set_9/CPL_pk.dat')
clcpl_9=np.loadtxt('./../kodama/output/parameter_set_9/CPL_cl.dat')
pkwn_9=np.loadtxt('./../kodama/output/parameter_set_9/wN1_pk.dat')
clwn_9=np.loadtxt('./../kodama/output/parameter_set_9/wN1_cl.dat')

#*******************************

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.loglog(pkcpl_1[:,0],pkcpl_1[:,1],'-r',label='cpl (parameters1)',alpha=1,linewidth=1)
ax.loglog(pkwn_1[:,0],pkwn_1[:,1],'-b',label='w(n=1) (parameters1)',alpha=0.3,linewidth=4)
ax.legend(loc='upper right', fancybox=True, framealpha=1)
ax.set_ylabel(r'P $(Mpc/h)^3$',fontsize=15)
ax.set_xlabel(r'k $(h/Mpc) $',fontsize=15)
ax.grid(which='minor',ls=":", c='black');

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.semilogx(clcpl_1[:,0],clcpl_1[:,1],'-r',label='cpl',alpha=1,linewidth=1)
ax.semilogx(clwn_1[:,0],clwn_1[:,1],'-b',label='w(n=1)',alpha=0.3,linewidth=4)
ax.semilogx(clcpl_6[:,0],clcpl_6[:,1],'-g',label='cpl',alpha=1,linewidth=1)
ax.semilogx(clwn_6[:,0],clwn_6[:,1],'-y',label='w(n=1)',alpha=0.3,linewidth=4)
ax.set_xlim()
ax.legend(loc='upper right', fancybox=True, framealpha=0.5);
